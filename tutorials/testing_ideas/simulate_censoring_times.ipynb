# %%
import numpy as np

from pycox import datasets
from lifelines.datasets import load_rossi
from sksurv.datasets import (
    load_aids,
    load_breast_cancer,
    load_flchain,
    load_gbsg2,
    load_whas500,
)
from sklearn.preprocessing import LabelEncoder


def get_dataset(name: str):
    if name == "metabric":
        df = datasets.metabric.read_df()
    elif name == "support":
        df = datasets.support.read_df()
    elif name == "gbsg":
        df = datasets.gbsg.read_df()
    elif name == "rossi":
        df = load_rossi()
        df = df.rename(columns={"week": "duration", "arrest": "event"})
    elif name == "aids":
        X, Y = load_aids()
        Y_unp = np.array(Y, dtype=[("event", "int"), ("duration", "float")])
        df = X.copy()
        df["event"] = Y_unp["event"]
        df["duration"] = Y_unp["duration"]
    elif name == "flchain":
        X, Y = load_flchain()
        Y_unp = np.array(Y, dtype=[("event", "int"), ("duration", "float")])
        df = X.copy()
        df["event"] = Y_unp["event"]
        df["duration"] = Y_unp["duration"]
    elif name == "gbsg2":
        X, Y = load_gbsg2()
        Y_unp = np.array(Y, dtype=[("event", "int"), ("duration", "float")])
        df = X.copy()
        df["event"] = Y_unp["event"]
        df["duration"] = Y_unp["duration"]
    elif name == "whas500":
        X, Y = load_whas500()
        Y_unp = np.array(Y, dtype=[("event", "int"), ("duration", "float")])
        df = X.copy()
        df["event"] = Y_unp["event"]
        df["duration"] = Y_unp["duration"]

    for col in df.columns:
        if df[col].dtype.name in ["object", "category"]:
            df[col] = LabelEncoder().fit_transform(df[col])

    duration_col = "duration"
    event_col = "event"
    
    df = df[df["duration"] > 0]

    X = df.drop(columns=[duration_col, event_col])
    Y = df[event_col]
    T = df[duration_col]

    time_horizons = np.linspace(T.min(), T.max(), num=5)[1:-1]

    return df, X, T, Y, time_horizons

# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from typing import Tuple
import optuna
import copy

from synthcity.plugins.models.time_to_event.tte_aft import WeibullAFTTimeToEvent
from synthcity.plugins.models.time_to_event.tte_coxph import CoxPHTimeToEvent
from synthcity.plugins.models.time_to_event.tte_rsf import RandomSurvivalForestTimeToEvent
from synthcity.plugins.models.time_to_event.tte_xgb import XGBTimeToEvent
from synthcity.plugins.models.time_to_event.tte_deephit import DeephitTimeToEvent
from synthcity.plugins.models.time_to_event.tte_date import DATETimeToEvent
from synthcity.plugins.models.time_to_event.tte_robust_date import RobustDATETimeToEvent
from synthcity.plugins.models.time_to_event.tte_tenn import TENNTimeToEvent

from synthcity.plugins.models.time_to_event.metrics import (
     expected_time_error,
     ranking_error,
     rush_error,
 )
from synthcity.plugins import Plugins
from adjutorium.utils.tester import evaluate_survival_estimator
from adjutorium.plugins.prediction.risk_estimation import RiskEstimation
from adjutorium.plugins.prediction.regression import Regression
from synthcity.plugins import Plugins

from sksurv.metrics import concordance_index_censored
from sklearn.model_selection import KFold

from adjutorium.utils.risk_estimation import generate_dataset_for_horizon

# %%
def constant_columns(dataframe: pd.DataFrame) -> list:
    """
    Drops constant value columns of pandas dataframe.
    """
    result = []
    for column in dataframe.columns:
        if len(dataframe[column].unique()) == 1:
            result.append(column)
    return result

def print_results(results):
    headers = ["Decensoring model", "Synth model", "synth_real CINDEX", "real_synth CINDEX", "synth_synth CINDEX"]
    out_results = []

    for tte_model in results:
        for synth_model in results[tte_model]:
            local = results[tte_model][synth_model]
            out_results.append([tte_model, synth_model, local["synth_real"]["c_index"], 
                               local["real_synth"]["c_index"], local["synth_synth"]["c_index"],
                               ])

    return pd.DataFrame(out_results, columns = headers)

def get_tte_model(name: str):
    if name == "tenn":
        return TENNTimeToEvent()
    elif name == "random_survival_forest":
        return RandomSurvivalForestTimeToEvent()
    elif name == "date":
        return DATETimeToEvent()
    elif name == "deephit":
        return RandomSurvivalForestTimeToEvent()
    elif name == "coxph":
        return CoxPHTimeToEvent()
    
    raise NotImplementedError(name)
    
def dataset_uncensoring(
    model_name: str, 
    X: pd.DataFrame, 
    T: pd.Series, 
    Y: pd.Series):
    
    tte_model = get_tte_model(model_name)

    # Uncensoring step
    tte_model.fit(X, T, E)
    
    pred_T = tte_model.predict(X)
    pred_T = pd.Series(pred_T, index=X.index)
    pred_T[Y == 1] = T[Y == 1]
    
    synth_baseline = X.copy()
    synth_baseline["event_time"] = pred_T

    return synth_baseline

def evaluate_test_dataset(X_train, T_train, Y_train,
                          X_test, T_test, Y_test,
                          time_horizons, model = "cox_ph", n_folds = 3):    
    predictor = RiskEstimation().get(model)
    
    const_cols = constant_columns(X_train)
    X_train = X_train.drop(columns = const_cols)
    X_test = X_test.drop(columns = const_cols)
    
    predictor.fit(X_train, T_train, Y_train)
    
    return evaluate_survival_estimator(
                                       [predictor] * n_folds, 
                                       X_test, T_test, Y_test, 
                                       time_horizons = time_horizons,
                                       n_folds = n_folds,
                                       metrics = ["c_index", "brier_score"],
                                       pretrained = True,
                                      )["str"]
def evaluate_dataset(X, T, Y, time_horizons, model = "cox_ph", n_folds = 3):    
    predictor = RiskEstimation().get(model)
    
    const_cols = constant_columns(X)
    X = X.drop(columns = const_cols)
    
    return evaluate_survival_estimator(predictor, 
                                       X, T, Y, 
                                       time_horizons = time_horizons,
                                       n_folds = n_folds,
                                       metrics = ["c_index", "brier_score"],
                                      )["str"]
    
def synthetic_survival(X, T, Y,
                       time_to_event_model = "tenn",
                       synth_model = "ctgan",
                      ):
    
    # Uncensoring
    uncensored_dataset = dataset_uncensoring(time_to_event_model, X, T, E)

    # Fit the synth generator
    generator = Plugins().get(synth_model)
    generator.fit(uncensored_dataset)

    synth_df = generator.generate(len(X))
    # 
    
    synth_eval_X = synth_df.drop(columns = ["event_time"])
    synth_eval_T = synth_df["event_time"]
    synth_eval_E = pd.Series([1] * len(X), index = synth_eval_X.index)
    
    return synth_eval_X, synth_eval_T, synth_eval_E

# %% [markdown]
# ## AIDS dataset

# %%
import pandas as pd

df, X_real, T_real, Y_real, time_horizons = get_dataset("aids")

X = df.drop(columns=["event", "duration"])
E = df["event"]
T = df["duration"]

X
# Out:
#        age    cd4  hemophil  ivdrug  karnof  priorzdv  raceth  sex  strat2  \
# 0     34.0  169.0         0       0       0      39.0       0    0       1
# 1     34.0  149.5         0       0       3      15.0       1    1       1
# 2     20.0   23.5         1       0       0       9.0       0    0       0
# 3     48.0   46.0         0       0       3      53.0       0    0       1
# 4     46.0   10.0         0       2       3      12.0       0    0       0
# ...    ...    ...       ...     ...     ...       ...     ...  ...     ...
# 1146  44.0   65.5         0       0       0     103.0       0    0       1
# 1147  41.0    7.5         0       0       2      20.0       1    0       0
# 1148  43.0  170.0         0       2       3      27.0       1    0       1
# 1149  44.0  282.5         0       2       2      12.0       0    0       1
# 1150  44.0  120.0         0       0       3      26.0       0    0       1
#
#       tx  txgrp
# 0      0      0
# 1      0      0
# 2      1      1
# 3      0      0
# 4      1      1
# ...   ..    ...
# 1146   1      1
# 1147   1      1
# 1148   0      0
# 1149   0      0
# 1150   1      1
#
# [1151 rows x 11 columns]

# %%
evaluate_dataset(X, T, E, time_horizons)
# Out:
# {'c_index': '0.7389 +/- 0.0531', 'brier_score': '0.0617 +/- 0.0034'}

# %%
results = {}
for tte_model in ["random_survival_forest", "date", "tenn", "deephit", "coxph"]:
    results[tte_model] = {}
    for synth_model in ["ctgan", "adsgan", "rtvae", "tvae"]:
        synth_eval_X, synth_eval_T, synth_eval_E = synthetic_survival(X, T, E, 
                                                                      time_to_event_model = tte_model, 
                                                                      synth_model = synth_model)

        try:
            eval_synth_synth = evaluate_dataset(synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_real_synth = evaluate_test_dataset(X, T, E, synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_synth_real = evaluate_test_dataset(synth_eval_X, synth_eval_T, synth_eval_E, X, T, E, time_horizons)
        except BaseException as e:
            print(" !!! evaluation failed ", tte_model, synth_model, e)
            continue
            
        results[tte_model][synth_model] = {
            "synth_synth": eval_synth_synth,
            "synth_real": eval_synth_real,
            "real_synth": eval_real_synth,
        }
        print(f"[{tte_model}][{synth_model}] >>> evaluation synth_synth={eval_synth_synth} synth_real={eval_synth_real} real_synth={eval_real_synth}")
# Out:
# [random_survival_forest][ctgan] >>> evaluation synth_synth={'c_index': '0.506 +/- 0.0147', 'brier_score': '0.1263 +/- 0.0131'} synth_real={'c_index': '0.6058 +/- 0.0342', 'brier_score': '0.0776 +/- 0.001'} real_synth={'c_index': '0.4802 +/- 0.0296', 'brier_score': '0.1447 +/- 0.0158'}
# [random_survival_forest][adsgan] >>> evaluation synth_synth={'c_index': '0.9147 +/- 0.0043', 'brier_score': '0.0771 +/- 0.0059'} synth_real={'c_index': '0.6922 +/- 0.0562', 'brier_score': '0.0999 +/- 0.004'} real_synth={'c_index': '0.8953 +/- 0.0077', 'brier_score': '0.222 +/- 0.0036'}
# [random_survival_forest][rtvae] >>> evaluation synth_synth={'c_index': '0.699 +/- 0.0294', 'brier_score': '0.1726 +/- 0.0012'} synth_real={'c_index': '0.5374 +/- 0.0374', 'brier_score': '0.1973 +/- 0.0136'} real_synth={'c_index': '0.6349 +/- 0.0177', 'brier_score': '0.3073 +/- 0.0113'}
# [random_survival_forest][tvae] >>> evaluation synth_synth={'c_index': '0.8738 +/- 0.0185', 'brier_score': '0.0792 +/- 0.0075'} synth_real={'c_index': '0.739 +/- 0.0403', 'brier_score': '0.066 +/- 0.0015'} real_synth={'c_index': '0.874 +/- 0.0239', 'brier_score': '0.0797 +/- 0.0083'}
# [date][ctgan] >>> evaluation synth_synth={'c_index': '0.5661 +/- 0.02', 'brier_score': '0.2127 +/- 0.0066'} synth_real={'c_index': '0.4084 +/- 0.0332', 'brier_score': '0.2517 +/- 0.0102'} real_synth={'c_index': '0.4987 +/- 0.0207', 'brier_score': '0.4043 +/- 0.0167'}
# [date][adsgan] >>> evaluation synth_synth={'c_index': '0.8112 +/- 0.0168', 'brier_score': '0.0547 +/- 0.005'} synth_real={'c_index': '0.6155 +/- 0.0056', 'brier_score': '0.2019 +/- 0.009'} real_synth={'c_index': '0.7719 +/- 0.022', 'brier_score': '0.1821 +/- 0.0119'}
# [date][rtvae] >>> evaluation synth_synth={'c_index': '0.8314 +/- 0.0316', 'brier_score': '0.0785 +/- 0.0036'} synth_real={'c_index': '0.6315 +/- 0.032', 'brier_score': '0.0677 +/- 0.0013'} real_synth={'c_index': '0.574 +/- 0.0401', 'brier_score': '0.1107 +/- 0.0071'}
# [date][tvae] >>> evaluation synth_synth={'c_index': '0.8508 +/- 0.0332', 'brier_score': '0.0922 +/- 0.0063'} synth_real={'c_index': '0.7176 +/- 0.0201', 'brier_score': '0.0752 +/- 0.0038'} real_synth={'c_index': '0.861 +/- 0.0261', 'brier_score': '0.1203 +/- 0.014'}
# [tenn][ctgan] >>> evaluation synth_synth={'c_index': '0.4574 +/- 0.0871', 'brier_score': '0.0375 +/- 0.0092'} synth_real={'c_index': '0.3389 +/- 0.0283', 'brier_score': '0.0662 +/- 0.0008'} real_synth={'c_index': '0.5597 +/- 0.0224', 'brier_score': '0.0408 +/- 0.0089'}
# [tenn][adsgan] >>> evaluation synth_synth={'c_index': '0.8611 +/- 0.004', 'brier_score': '0.035 +/- 0.0015'} synth_real={'c_index': '0.7035 +/- 0.056', 'brier_score': '0.1191 +/- 0.0072'} real_synth={'c_index': '0.8201 +/- 0.0127', 'brier_score': '0.1206 +/- 0.0035'}
# [tenn][rtvae] >>> evaluation synth_synth={'c_index': '0.7454 +/- 0.0207', 'brier_score': '0.1532 +/- 0.0089'} synth_real={'c_index': '0.497 +/- 0.0201', 'brier_score': '0.1485 +/- 0.0068'} real_synth={'c_index': '0.42 +/- 0.0175', 'brier_score': '0.2967 +/- 0.002'}
# [tenn][tvae] >>> evaluation synth_synth={'c_index': '0.6319 +/- 0.1371', 'brier_score': '0.0103 +/- 0.0016'} synth_real={'c_index': '0.518 +/- 0.0112', 'brier_score': '0.0692 +/- 0.0011'} real_synth={'c_index': '0.8867 +/- 0.0667', 'brier_score': '0.0161 +/- 0.0012'}
# [deephit][ctgan] >>> evaluation synth_synth={'c_index': '0.5288 +/- 0.0153', 'brier_score': '0.1943 +/- 0.0059'} synth_real={'c_index': '0.5444 +/- 0.0361', 'brier_score': '0.1073 +/- 0.0027'} real_synth={'c_index': '0.471 +/- 0.02', 'brier_score': '0.2517 +/- 0.0094'}
# [deephit][adsgan] >>> evaluation synth_synth={'c_index': '0.8992 +/- 0.0061', 'brier_score': '0.0289 +/- 0.0053'} synth_real={'c_index': '0.6345 +/- 0.027', 'brier_score': '0.1758 +/- 0.005'} real_synth={'c_index': '0.8491 +/- 0.0104', 'brier_score': '0.412 +/- 0.0095'}
# [deephit][rtvae] >>> evaluation synth_synth={'c_index': '0.699 +/- 0.0294', 'brier_score': '0.1726 +/- 0.0012'} synth_real={'c_index': '0.5374 +/- 0.0374', 'brier_score': '0.1973 +/- 0.0136'} real_synth={'c_index': '0.6349 +/- 0.0177', 'brier_score': '0.3073 +/- 0.0113'}
# [deephit][tvae] >>> evaluation synth_synth={'c_index': '0.8286 +/- 0.005', 'brier_score': '0.0663 +/- 0.0069'} synth_real={'c_index': '0.738 +/- 0.0293', 'brier_score': '0.0657 +/- 0.0012'} real_synth={'c_index': '0.8296 +/- 0.0169', 'brier_score': '0.065 +/- 0.0071'}
# [coxph][ctgan] >>> evaluation synth_synth={'c_index': '0.4762 +/- 0.0563', 'brier_score': '0.0544 +/- 0.0175'} synth_real={'c_index': '0.6146 +/- 0.0326', 'brier_score': '0.0648 +/- 0.0007'} real_synth={'c_index': '0.4225 +/- 0.0768', 'brier_score': '0.0567 +/- 0.0179'}
# [coxph][adsgan] >>> evaluation synth_synth={'c_index': '0.0022 +/- 0.0035', 'brier_score': '0.0009 +/- 0.0014'} synth_real={'c_index': '0.7156 +/- 0.0209', 'brier_score': '0.0697 +/- 0.0013'} real_synth={'c_index': '0.0977 +/- 0.1564', 'brier_score': '0.009 +/- 0.0145'}
# [coxph][rtvae] >>> evaluation synth_synth={'c_index': '0.7358 +/- 0.0088', 'brier_score': '0.1611 +/- 0.0072'} synth_real={'c_index': '0.3064 +/- 0.0683', 'brier_score': '0.095 +/- 0.0032'} real_synth={'c_index': '0.4004 +/- 0.0414', 'brier_score': '0.27 +/- 0.0143'}
# [coxph][tvae] >>> evaluation synth_synth={'c_index': '0.0 +/- 0.0', 'brier_score': '0.0 +/- 0.0'} synth_real={'c_index': '0.7456 +/- 0.043', 'brier_score': '0.0698 +/- 0.0012'} real_synth={'c_index': '0.0 +/- 0.0', 'brier_score': '0.0 +/- 0.0'}

# %%
print_results(results)
# Out:
#          Decensoring model Synth model  synth_real CINDEX  real_synth CINDEX  \
# 0   random_survival_forest       ctgan  0.6058 +/- 0.0342  0.4802 +/- 0.0296
# 1   random_survival_forest      adsgan  0.6922 +/- 0.0562  0.8953 +/- 0.0077
# 2   random_survival_forest       rtvae  0.5374 +/- 0.0374  0.6349 +/- 0.0177
# 3   random_survival_forest        tvae   0.739 +/- 0.0403   0.874 +/- 0.0239
# 4                     date       ctgan  0.4084 +/- 0.0332  0.4987 +/- 0.0207
# 5                     date      adsgan  0.6155 +/- 0.0056   0.7719 +/- 0.022
# 6                     date       rtvae   0.6315 +/- 0.032   0.574 +/- 0.0401
# 7                     date        tvae  0.7176 +/- 0.0201   0.861 +/- 0.0261
# 8                     tenn       ctgan  0.3389 +/- 0.0283  0.5597 +/- 0.0224
# 9                     tenn      adsgan   0.7035 +/- 0.056  0.8201 +/- 0.0127
# 10                    tenn       rtvae   0.497 +/- 0.0201    0.42 +/- 0.0175
# 11                    tenn        tvae   0.518 +/- 0.0112  0.8867 +/- 0.0667
# 12                 deephit       ctgan  0.5444 +/- 0.0361     0.471 +/- 0.02
# 13                 deephit      adsgan   0.6345 +/- 0.027  0.8491 +/- 0.0104
# 14                 deephit       rtvae  0.5374 +/- 0.0374  0.6349 +/- 0.0177
# 15                 deephit        tvae   0.738 +/- 0.0293  0.8296 +/- 0.0169
# 16                   coxph       ctgan  0.6146 +/- 0.0326  0.4225 +/- 0.0768
# 17                   coxph      adsgan  0.7156 +/- 0.0209  0.0977 +/- 0.1564
# 18                   coxph       rtvae  0.3064 +/- 0.0683  0.4004 +/- 0.0414
# 19                   coxph        tvae   0.7456 +/- 0.043        0.0 +/- 0.0
#
#    synth_synth CINDEX
# 0    0.506 +/- 0.0147
# 1   0.9147 +/- 0.0043
# 2    0.699 +/- 0.0294
# 3   0.8738 +/- 0.0185
# 4     0.5661 +/- 0.02
# 5   0.8112 +/- 0.0168
# 6   0.8314 +/- 0.0316
# 7   0.8508 +/- 0.0332
# 8   0.4574 +/- 0.0871
# 9    0.8611 +/- 0.004
# 10  0.7454 +/- 0.0207
# 11  0.6319 +/- 0.1371
# 12  0.5288 +/- 0.0153
# 13  0.8992 +/- 0.0061
# 14   0.699 +/- 0.0294
# 15   0.8286 +/- 0.005
# 16  0.4762 +/- 0.0563
# 17  0.0022 +/- 0.0035
# 18  0.7358 +/- 0.0088
# 19        0.0 +/- 0.0

# %% [markdown]
# ## Metabric dataset

# %%
import pandas as pd

df, X_real, T_real, Y_real, time_horizons = get_dataset("metabric")
df = df[df["duration"] > 0]

X = df.drop(columns=["event", "duration"])
E = df["event"]
T = df["duration"]

X
# Out:
#             x0        x1         x2        x3   x4   x5   x6   x7         x8
# 0     5.603834  7.811392  10.797988  5.967607  1.0  1.0  0.0  1.0  56.840000
# 1     5.284882  9.581043  10.204620  5.664970  1.0  0.0  0.0  1.0  85.940002
# 2     5.920251  6.776564  12.431715  5.873857  0.0  1.0  0.0  1.0  48.439999
# 3     6.654017  5.341846   8.646379  5.655888  0.0  0.0  0.0  0.0  66.910004
# 4     5.456747  5.339741  10.555724  6.008429  1.0  0.0  0.0  1.0  67.849998
# ...        ...       ...        ...       ...  ...  ...  ...  ...        ...
# 1899  5.946987  5.370492  12.345780  5.741395  1.0  1.0  0.0  1.0  76.839996
# 1900  5.339228  5.408853  12.176101  5.693043  1.0  1.0  0.0  1.0  63.090000
# 1901  5.901610  5.272237  14.200950  6.139390  0.0  0.0  0.0  1.0  57.770000
# 1902  6.818109  5.372744  11.652624  6.077852  1.0  0.0  0.0  1.0  58.889999
# 1903  5.725708  5.449718   9.680736  6.595955  1.0  1.0  0.0  0.0  60.630001
#
# [1903 rows x 9 columns]

# %%
evaluate_dataset(X, T, E, time_horizons)
# Out:
# {'c_index': '0.6333 +/- 0.0078', 'brier_score': '0.1887 +/- 0.009'}

# %%
results = {}
for tte_model in ["random_survival_forest", "date", "tenn", "deephit", "coxph"]:
    results[tte_model] = {}
    for synth_model in ["ctgan", "adsgan", "rtvae", "tvae"]:
        synth_eval_X, synth_eval_T, synth_eval_E = synthetic_survival(X, T, E, 
                                                                      time_to_event_model = tte_model, 
                                                                      synth_model = synth_model)

        try:
            eval_synth_synth = evaluate_dataset(synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_real_synth = evaluate_test_dataset(X, T, E, synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_synth_real = evaluate_test_dataset(synth_eval_X, synth_eval_T, synth_eval_E, X, T, E, time_horizons)
        except BaseException as e:
            print(" !!! evaluation failed ", tte_model, synth_model, e)
            continue
            
        results[tte_model][synth_model] = {
            "synth_synth": eval_synth_synth,
            "synth_real": eval_synth_real,
            "real_synth": eval_real_synth,
        }
        print(f"[{tte_model}][{synth_model}] >>> evaluation synth_synth={eval_synth_synth} synth_real={eval_synth_real} real_synth={eval_real_synth}")
# Out:
# [random_survival_forest][ctgan] >>> evaluation synth_synth={'c_index': '0.5652 +/- 0.0151', 'brier_score': '0.2015 +/- 0.0021'} synth_real={'c_index': '0.4484 +/- 0.0169', 'brier_score': '0.2614 +/- 0.0088'} real_synth={'c_index': '0.4778 +/- 0.012', 'brier_score': '0.2648 +/- 0.0058'}
# [random_survival_forest][adsgan] >>> evaluation synth_synth={'c_index': '0.735 +/- 0.0041', 'brier_score': '0.0713 +/- 0.0052'} synth_real={'c_index': '0.5444 +/- 0.0233', 'brier_score': '0.2885 +/- 0.0169'} real_synth={'c_index': '0.6237 +/- 0.0097', 'brier_score': '0.1896 +/- 0.0045'}
# [random_survival_forest][rtvae] >>> evaluation synth_synth={'c_index': '0.6251 +/- 0.0222', 'brier_score': '0.1457 +/- 0.0008'} synth_real={'c_index': '0.568 +/- 0.008', 'brier_score': '0.222 +/- 0.0161'} real_synth={'c_index': '0.478 +/- 0.0135', 'brier_score': '0.2007 +/- 0.003'}
# [random_survival_forest][tvae] >>> evaluation synth_synth={'c_index': '0.7713 +/- 0.0074', 'brier_score': '0.1494 +/- 0.0004'} synth_real={'c_index': '0.6322 +/- 0.0178', 'brier_score': '0.2069 +/- 0.009'} real_synth={'c_index': '0.7361 +/- 0.0056', 'brier_score': '0.1664 +/- 0.0038'}
# [date][ctgan] >>> evaluation synth_synth={'c_index': '0.6062 +/- 0.0117', 'brier_score': '0.1791 +/- 0.0016'} synth_real={'c_index': '0.5264 +/- 0.0239', 'brier_score': '0.2408 +/- 0.0161'} real_synth={'c_index': '0.4645 +/- 0.0048', 'brier_score': '0.2405 +/- 0.0065'}
# [date][adsgan] >>> evaluation synth_synth={'c_index': '0.8269 +/- 0.0112', 'brier_score': '0.4198 +/- 0.0021'} synth_real={'c_index': '0.5059 +/- 0.0093', 'brier_score': '0.4644 +/- 0.0039'} real_synth={'c_index': '0.6945 +/- 0.0059', 'brier_score': '0.1529 +/- 0.0014'}
# [date][rtvae] >>> evaluation synth_synth={'c_index': '0.6213 +/- 0.0106', 'brier_score': '0.1528 +/- 0.0015'} synth_real={'c_index': '0.514 +/- 0.0043', 'brier_score': '0.2421 +/- 0.0161'} real_synth={'c_index': '0.5143 +/- 0.0035', 'brier_score': '0.2132 +/- 0.0052'}
# [date][tvae] >>> evaluation synth_synth={'c_index': '0.7695 +/- 0.0109', 'brier_score': '0.1183 +/- 0.0012'} synth_real={'c_index': '0.6341 +/- 0.0166', 'brier_score': '0.2275 +/- 0.015'} real_synth={'c_index': '0.7012 +/- 0.0096', 'brier_score': '0.163 +/- 0.0008'}
# [tenn][ctgan] >>> evaluation synth_synth={'c_index': '0.5719 +/- 0.0092', 'brier_score': '0.1978 +/- 0.0031'} synth_real={'c_index': '0.581 +/- 0.0105', 'brier_score': '0.2251 +/- 0.0124'} real_synth={'c_index': '0.5172 +/- 0.0154', 'brier_score': '0.2685 +/- 0.0017'}
# [tenn][adsgan] >>> evaluation synth_synth={'c_index': '0.7994 +/- 0.039', 'brier_score': '0.0656 +/- 0.0052'} synth_real={'c_index': '0.4897 +/- 0.0206', 'brier_score': '0.3459 +/- 0.0065'} real_synth={'c_index': '0.9182 +/- 0.0098', 'brier_score': '0.1154 +/- 0.0003'}
# [tenn][rtvae] >>> evaluation synth_synth={'c_index': '0.7617 +/- 0.0102', 'brier_score': '0.1145 +/- 0.0013'} synth_real={'c_index': '0.5674 +/- 0.0152', 'brier_score': '0.2345 +/- 0.0145'} real_synth={'c_index': '0.5509 +/- 0.0121', 'brier_score': '0.1884 +/- 0.0026'}
# [tenn][tvae] >>> evaluation synth_synth={'c_index': '0.8072 +/- 0.005', 'brier_score': '0.1073 +/- 0.0038'} synth_real={'c_index': '0.6258 +/- 0.0167', 'brier_score': '0.2462 +/- 0.0127'} real_synth={'c_index': '0.7252 +/- 0.0065', 'brier_score': '0.163 +/- 0.0016'}
# [deephit][ctgan] >>> evaluation synth_synth={'c_index': '0.565 +/- 0.0155', 'brier_score': '0.1658 +/- 0.0041'} synth_real={'c_index': '0.5174 +/- 0.0096', 'brier_score': '0.2406 +/- 0.0154'} real_synth={'c_index': '0.5048 +/- 0.0079', 'brier_score': '0.2785 +/- 0.004'}
# [deephit][adsgan] >>> evaluation synth_synth={'c_index': '0.8626 +/- 0.0271', 'brier_score': '0.3639 +/- 0.0044'} synth_real={'c_index': '0.5226 +/- 0.0225', 'brier_score': '0.5105 +/- 0.0212'} real_synth={'c_index': '0.4681 +/- 0.014', 'brier_score': '0.225 +/- 0.0037'}
# [deephit][rtvae] >>> evaluation synth_synth={'c_index': '0.6251 +/- 0.0222', 'brier_score': '0.1457 +/- 0.0008'} synth_real={'c_index': '0.568 +/- 0.008', 'brier_score': '0.222 +/- 0.0161'} real_synth={'c_index': '0.478 +/- 0.0135', 'brier_score': '0.2007 +/- 0.003'}
# [deephit][tvae] >>> evaluation synth_synth={'c_index': '0.7713 +/- 0.0074', 'brier_score': '0.1494 +/- 0.0004'} synth_real={'c_index': '0.6322 +/- 0.0178', 'brier_score': '0.2069 +/- 0.009'} real_synth={'c_index': '0.7361 +/- 0.0056', 'brier_score': '0.1664 +/- 0.0038'}
# [coxph][ctgan] >>> evaluation synth_synth={'c_index': '0.5594 +/- 0.0091', 'brier_score': '0.177 +/- 0.0004'} synth_real={'c_index': '0.5612 +/- 0.023', 'brier_score': '0.2299 +/- 0.0162'} real_synth={'c_index': '0.5084 +/- 0.0126', 'brier_score': '0.2462 +/- 0.0042'}
# [coxph][adsgan] >>> evaluation synth_synth={'c_index': '0.8171 +/- 0.0027', 'brier_score': '0.3887 +/- 0.0011'} synth_real={'c_index': '0.5018 +/- 0.0251', 'brier_score': '0.5182 +/- 0.016'} real_synth={'c_index': '0.6001 +/- 0.0119', 'brier_score': '0.205 +/- 0.0056'}
# [coxph][rtvae] >>> evaluation synth_synth={'c_index': '0.6643 +/- 0.0122', 'brier_score': '0.1269 +/- 0.0015'} synth_real={'c_index': '0.525 +/- 0.0131', 'brier_score': '0.2693 +/- 0.0221'} real_synth={'c_index': '0.522 +/- 0.0116', 'brier_score': '0.1869 +/- 0.0026'}
# [coxph][tvae] >>> evaluation synth_synth={'c_index': '0.7609 +/- 0.0119', 'brier_score': '0.1178 +/- 0.0033'} synth_real={'c_index': '0.6377 +/- 0.014', 'brier_score': '0.2362 +/- 0.0089'} real_synth={'c_index': '0.7039 +/- 0.0113', 'brier_score': '0.1694 +/- 0.0029'}

# %%
print_results(results)
# Out:
#          Decensoring model Synth model  synth_real CINDEX  real_synth CINDEX  \
# 0   random_survival_forest       ctgan  0.4484 +/- 0.0169   0.4778 +/- 0.012
# 1   random_survival_forest      adsgan  0.5444 +/- 0.0233  0.6237 +/- 0.0097
# 2   random_survival_forest       rtvae    0.568 +/- 0.008   0.478 +/- 0.0135
# 3   random_survival_forest        tvae  0.6322 +/- 0.0178  0.7361 +/- 0.0056
# 4                     date       ctgan  0.5264 +/- 0.0239  0.4645 +/- 0.0048
# 5                     date      adsgan  0.5059 +/- 0.0093  0.6945 +/- 0.0059
# 6                     date       rtvae   0.514 +/- 0.0043  0.5143 +/- 0.0035
# 7                     date        tvae  0.6341 +/- 0.0166  0.7012 +/- 0.0096
# 8                     tenn       ctgan   0.581 +/- 0.0105  0.5172 +/- 0.0154
# 9                     tenn      adsgan  0.4897 +/- 0.0206  0.9182 +/- 0.0098
# 10                    tenn       rtvae  0.5674 +/- 0.0152  0.5509 +/- 0.0121
# 11                    tenn        tvae  0.6258 +/- 0.0167  0.7252 +/- 0.0065
# 12                 deephit       ctgan  0.5174 +/- 0.0096  0.5048 +/- 0.0079
# 13                 deephit      adsgan  0.5226 +/- 0.0225   0.4681 +/- 0.014
# 14                 deephit       rtvae    0.568 +/- 0.008   0.478 +/- 0.0135
# 15                 deephit        tvae  0.6322 +/- 0.0178  0.7361 +/- 0.0056
# 16                   coxph       ctgan   0.5612 +/- 0.023  0.5084 +/- 0.0126
# 17                   coxph      adsgan  0.5018 +/- 0.0251  0.6001 +/- 0.0119
# 18                   coxph       rtvae   0.525 +/- 0.0131   0.522 +/- 0.0116
# 19                   coxph        tvae   0.6377 +/- 0.014  0.7039 +/- 0.0113
#
#    synth_synth CINDEX
# 0   0.5652 +/- 0.0151
# 1    0.735 +/- 0.0041
# 2   0.6251 +/- 0.0222
# 3   0.7713 +/- 0.0074
# 4   0.6062 +/- 0.0117
# 5   0.8269 +/- 0.0112
# 6   0.6213 +/- 0.0106
# 7   0.7695 +/- 0.0109
# 8   0.5719 +/- 0.0092
# 9    0.7994 +/- 0.039
# 10  0.7617 +/- 0.0102
# 11   0.8072 +/- 0.005
# 12   0.565 +/- 0.0155
# 13  0.8626 +/- 0.0271
# 14  0.6251 +/- 0.0222
# 15  0.7713 +/- 0.0074
# 16  0.5594 +/- 0.0091
# 17  0.8171 +/- 0.0027
# 18  0.6643 +/- 0.0122
# 19  0.7609 +/- 0.0119

# %% [markdown]
# ## SUPPORT dataset

# %%
import pandas as pd

df, X_real, T_real, Y_real, time_horizons = get_dataset("support")
df = df[df["duration"] > 0]

X = df.drop(columns=["event", "duration"])
E = df["event"]
T = df["duration"]

X
# Out:
#              x0   x1   x2   x3   x4   x5   x6     x7     x8    x9        x10  \
# 0     82.709961  1.0  2.0  1.0  0.0  0.0  0.0  160.0   55.0  16.0  38.195309
# 1     79.660950  1.0  0.0  1.0  0.0  0.0  1.0   54.0   67.0  16.0  38.000000
# 2     23.399990  1.0  2.0  3.0  0.0  0.0  1.0   87.0  144.0  45.0  37.296879
# 3     53.075989  1.0  4.0  3.0  0.0  0.0  0.0   55.0  100.0  18.0  36.000000
# 4     71.794983  0.0  1.0  1.0  0.0  0.0  0.0   65.0  135.0  40.0  38.593750
# ...         ...  ...  ...  ...  ...  ...  ...    ...    ...   ...        ...
# 8868  81.064941  0.0  4.0  1.0  0.0  0.0  1.0  111.0  110.0  34.0  39.593750
# 8869  72.560966  0.0  2.0  1.0  0.0  0.0  1.0   53.0   74.0  28.0  34.695309
# 8870  63.228001  0.0  1.0  1.0  0.0  0.0  2.0   95.0  110.0  22.0  38.695309
# 8871  75.405937  0.0  2.0  1.0  1.0  0.0  2.0  109.0  110.0  30.0  36.195309
# 8872  39.534969  1.0  3.0  2.0  0.0  0.0  1.0   77.0  120.0  24.0  38.000000
#
#         x11        x12       x13
# 0     142.0  19.000000  1.099854
# 1     142.0  10.000000  0.899902
# 2     130.0   5.199219  1.199951
# 3     135.0   8.699219  0.799927
# 4     146.0   0.099991  0.399963
# ...     ...        ...       ...
# 8868  135.0  13.000000  1.500000
# 8869  139.0   7.899414  1.899902
# 8870  132.0   7.799805  1.500000
# 8871  140.0  15.398438  0.899902
# 8872  135.0  20.398438  1.299805
#
# [8873 rows x 14 columns]

# %%
evaluate_dataset(X, T, E, time_horizons)
# Out:
# {'c_index': '0.5706 +/- 0.0054', 'brier_score': '0.2084 +/- 0.004'}

# %%
results = {}
for tte_model in ["random_survival_forest", "date", "tenn", "deephit", "coxph"]:
    results[tte_model] = {}
    for synth_model in ["ctgan", "adsgan", "rtvae", "tvae"]:
        synth_eval_X, synth_eval_T, synth_eval_E = synthetic_survival(X, T, E, 
                                                                      time_to_event_model = tte_model, 
                                                                      synth_model = synth_model)

        try:
            eval_synth_synth = evaluate_dataset(synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_real_synth = evaluate_test_dataset(X, T, E, synth_eval_X, synth_eval_T, synth_eval_E, time_horizons)
            eval_synth_real = evaluate_test_dataset(synth_eval_X, synth_eval_T, synth_eval_E, X, T, E, time_horizons)
        except BaseException as e:
            print(" !!! evaluation failed ", tte_model, synth_model, e)
            continue
            
        results[tte_model][synth_model] = {
            "synth_synth": eval_synth_synth,
            "synth_real": eval_synth_real,
            "real_synth": eval_real_synth,
        }
        print(f"[{tte_model}][{synth_model}] >>> evaluation synth_synth={eval_synth_synth} synth_real={eval_synth_real} real_synth={eval_real_synth}")
# Out:
# [random_survival_forest][ctgan] >>> evaluation synth_synth={'c_index': '0.5612 +/- 0.0055', 'brier_score': '0.1349 +/- 0.0034'} synth_real={'c_index': '0.531 +/- 0.0067', 'brier_score': '0.2416 +/- 0.008'} real_synth={'c_index': '0.5352 +/- 0.006', 'brier_score': '0.1646 +/- 0.0031'}
# [random_survival_forest][adsgan] >>> evaluation synth_synth={'c_index': '0.8282 +/- 0.0042', 'brier_score': '0.0664 +/- 0.0034'} synth_real={'c_index': '0.4582 +/- 0.0061', 'brier_score': '0.3193 +/- 0.0081'} real_synth={'c_index': '0.343 +/- 0.0051', 'brier_score': '0.2332 +/- 0.0023'}
# [random_survival_forest][rtvae] >>> evaluation synth_synth={'c_index': '0.5753 +/- 0.0026', 'brier_score': '0.1556 +/- 0.0014'} synth_real={'c_index': '0.5089 +/- 0.0022', 'brier_score': '0.2506 +/- 0.007'} real_synth={'c_index': '0.4723 +/- 0.0019', 'brier_score': '0.2087 +/- 0.0033'}
# [random_survival_forest][tvae] >>> evaluation synth_synth={'c_index': '0.6511 +/- 0.0049', 'brier_score': '0.055 +/- 0.003'} synth_real={'c_index': '0.5617 +/- 0.0018', 'brier_score': '0.2644 +/- 0.0107'} real_synth={'c_index': '0.616 +/- 0.0064', 'brier_score': '0.1152 +/- 0.0008'}
# [date][ctgan] >>> evaluation synth_synth={'c_index': '0.5251 +/- 0.0028', 'brier_score': '0.0724 +/- 0.0015'} synth_real={'c_index': '0.5384 +/- 0.0053', 'brier_score': '0.2781 +/- 0.0109'} real_synth={'c_index': '0.5185 +/- 0.0068', 'brier_score': '0.1276 +/- 0.0013'}
# [date][adsgan] >>> evaluation synth_synth={'c_index': '0.796 +/- 0.0061', 'brier_score': '0.188 +/- 0.1776'} synth_real={'c_index': '0.5377 +/- 0.0024', 'brier_score': '0.2929 +/- 0.0093'} real_synth={'c_index': '0.7224 +/- 0.0044', 'brier_score': '0.1562 +/- 0.0004'}
# [date][rtvae] >>> evaluation synth_synth={'c_index': '0.6294 +/- 0.0032', 'brier_score': '0.1348 +/- 0.0018'} synth_real={'c_index': '0.5288 +/- 0.0089', 'brier_score': '0.2626 +/- 0.0053'} real_synth={'c_index': '0.548 +/- 0.006', 'brier_score': '0.1901 +/- 0.0045'}
# [date][tvae] >>> evaluation synth_synth={'c_index': '0.5869 +/- 0.0089', 'brier_score': '0.0643 +/- 0.0019'} synth_real={'c_index': '0.5543 +/- 0.006', 'brier_score': '0.2676 +/- 0.0102'} real_synth={'c_index': '0.556 +/- 0.0102', 'brier_score': '0.1199 +/- 0.0008'}
# [tenn][ctgan] >>> evaluation synth_synth={'c_index': '0.573 +/- 0.007', 'brier_score': '0.1325 +/- 0.0042'} synth_real={'c_index': '0.5212 +/- 0.0013', 'brier_score': '0.2428 +/- 0.0088'} real_synth={'c_index': '0.5249 +/- 0.0068', 'brier_score': '0.165 +/- 0.0029'}
# [tenn][adsgan] >>> evaluation synth_synth={'c_index': '0.8055 +/- 0.0078', 'brier_score': '0.0388 +/- 0.001'} synth_real={'c_index': '0.519 +/- 0.0053', 'brier_score': '0.3026 +/- 0.0105'} real_synth={'c_index': '0.7002 +/- 0.0067', 'brier_score': '0.141 +/- 0.0013'}
# [tenn][rtvae] >>> evaluation synth_synth={'c_index': '0.5877 +/- 0.0039', 'brier_score': '0.1256 +/- 0.0014'} synth_real={'c_index': '0.5249 +/- 0.0083', 'brier_score': '0.26 +/- 0.006'} real_synth={'c_index': '0.5181 +/- 0.0063', 'brier_score': '0.1735 +/- 0.0018'}
# [tenn][tvae] >>> evaluation synth_synth={'c_index': '0.6054 +/- 0.0035', 'brier_score': '0.0833 +/- 0.1312'} synth_real={'c_index': '0.5484 +/- 0.0044', 'brier_score': '0.3265 +/- 0.0122'} real_synth={'c_index': '0.5798 +/- 0.0071', 'brier_score': '0.0992 +/- 0.001'}
# [deephit][ctgan] >>> evaluation synth_synth={'c_index': '0.5462 +/- 0.0062', 'brier_score': '0.1683 +/- 0.0008'} synth_real={'c_index': '0.5389 +/- 0.004', 'brier_score': '0.2399 +/- 0.0061'} real_synth={'c_index': '0.5378 +/- 0.0083', 'brier_score': '0.1964 +/- 0.0011'}
# [deephit][adsgan] >>> evaluation synth_synth={'c_index': '0.7107 +/- 0.0047', 'brier_score': '0.3653 +/- 0.0011'} synth_real={'c_index': '0.5388 +/- 0.0015', 'brier_score': '0.4551 +/- 0.0072'} real_synth={'c_index': '0.6954 +/- 0.0055', 'brier_score': '0.1706 +/- 0.0019'}
# [deephit][rtvae] >>> evaluation synth_synth={'c_index': '0.5753 +/- 0.0026', 'brier_score': '0.1556 +/- 0.0014'} synth_real={'c_index': '0.5089 +/- 0.0022', 'brier_score': '0.2506 +/- 0.007'} real_synth={'c_index': '0.4723 +/- 0.0019', 'brier_score': '0.2087 +/- 0.0033'}
# [deephit][tvae] >>> evaluation synth_synth={'c_index': '0.6505 +/- 0.005', 'brier_score': '0.053 +/- 0.0062'} synth_real={'c_index': '0.5516 +/- 0.0027', 'brier_score': '0.2624 +/- 0.0107'} real_synth={'c_index': '0.6135 +/- 0.0043', 'brier_score': '0.1161 +/- 0.0023'}
# [coxph][ctgan] >>> evaluation synth_synth={'c_index': '0.5107 +/- 0.0043', 'brier_score': '0.1122 +/- 0.0011'} synth_real={'c_index': '0.5405 +/- 0.0073', 'brier_score': '0.2662 +/- 0.0086'} real_synth={'c_index': '0.5163 +/- 0.0082', 'brier_score': '0.1634 +/- 0.0021'}
# [coxph][adsgan] >>> evaluation synth_synth={'c_index': '0.6809 +/- 0.0094', 'brier_score': '0.6709 +/- 0.0004'} synth_real={'c_index': '0.4628 +/- 0.0052', 'brier_score': '0.6047 +/- 0.0076'} real_synth={'c_index': '0.4092 +/- 0.0079', 'brier_score': '0.1946 +/- 0.0012'}
# [coxph][rtvae] >>> evaluation synth_synth={'c_index': '0.5706 +/- 0.0094', 'brier_score': '0.1114 +/- 0.0019'} synth_real={'c_index': '0.4818 +/- 0.0091', 'brier_score': '0.279 +/- 0.0085'} real_synth={'c_index': '0.4739 +/- 0.0101', 'brier_score': '0.1813 +/- 0.0023'}
# [coxph][tvae] >>> evaluation synth_synth={'c_index': '0.6502 +/- 0.0014', 'brier_score': '0.2606 +/- 0.0036'} synth_real={'c_index': '0.5333 +/- 0.0028', 'brier_score': '0.4148 +/- 0.0119'} real_synth={'c_index': '0.6179 +/- 0.0031', 'brier_score': '0.102 +/- 0.0008'}

# %%
print_results(results)
# Out:
#          Decensoring model Synth model  synth_real CINDEX  real_synth CINDEX  \
# 0   random_survival_forest       ctgan   0.531 +/- 0.0067   0.5352 +/- 0.006
# 1   random_survival_forest      adsgan  0.4582 +/- 0.0061   0.343 +/- 0.0051
# 2   random_survival_forest       rtvae  0.5089 +/- 0.0022  0.4723 +/- 0.0019
# 3   random_survival_forest        tvae  0.5617 +/- 0.0018   0.616 +/- 0.0064
# 4                     date       ctgan  0.5384 +/- 0.0053  0.5185 +/- 0.0068
# 5                     date      adsgan  0.5377 +/- 0.0024  0.7224 +/- 0.0044
# 6                     date       rtvae  0.5288 +/- 0.0089    0.548 +/- 0.006
# 7                     date        tvae   0.5543 +/- 0.006   0.556 +/- 0.0102
# 8                     tenn       ctgan  0.5212 +/- 0.0013  0.5249 +/- 0.0068
# 9                     tenn      adsgan   0.519 +/- 0.0053  0.7002 +/- 0.0067
# 10                    tenn       rtvae  0.5249 +/- 0.0083  0.5181 +/- 0.0063
# 11                    tenn        tvae  0.5484 +/- 0.0044  0.5798 +/- 0.0071
# 12                 deephit       ctgan   0.5389 +/- 0.004  0.5378 +/- 0.0083
# 13                 deephit      adsgan  0.5388 +/- 0.0015  0.6954 +/- 0.0055
# 14                 deephit       rtvae  0.5089 +/- 0.0022  0.4723 +/- 0.0019
# 15                 deephit        tvae  0.5516 +/- 0.0027  0.6135 +/- 0.0043
# 16                   coxph       ctgan  0.5405 +/- 0.0073  0.5163 +/- 0.0082
# 17                   coxph      adsgan  0.4628 +/- 0.0052  0.4092 +/- 0.0079
# 18                   coxph       rtvae  0.4818 +/- 0.0091  0.4739 +/- 0.0101
# 19                   coxph        tvae  0.5333 +/- 0.0028  0.6179 +/- 0.0031
#
#    synth_synth CINDEX
# 0   0.5612 +/- 0.0055
# 1   0.8282 +/- 0.0042
# 2   0.5753 +/- 0.0026
# 3   0.6511 +/- 0.0049
# 4   0.5251 +/- 0.0028
# 5    0.796 +/- 0.0061
# 6   0.6294 +/- 0.0032
# 7   0.5869 +/- 0.0089
# 8     0.573 +/- 0.007
# 9   0.8055 +/- 0.0078
# 10  0.5877 +/- 0.0039
# 11  0.6054 +/- 0.0035
# 12  0.5462 +/- 0.0062
# 13  0.7107 +/- 0.0047
# 14  0.5753 +/- 0.0026
# 15   0.6505 +/- 0.005
# 16  0.5107 +/- 0.0043
# 17  0.6809 +/- 0.0094
# 18  0.5706 +/- 0.0094
# 19  0.6502 +/- 0.0014
