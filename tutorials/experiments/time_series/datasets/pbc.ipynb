# %%
from synthcity.utils.datasets.time_series.pbc import PBCDataloader
from synthcity.plugins.core.dataloader import (
     TimeSeriesDataLoader,
     TimeSeriesSurvivalDataLoader,
 )
import numpy as np
import pandas as pd
import tabulate

static, temporal, temporal_horizons, outcome = PBCDataloader(as_numpy = True).load()
T, E = outcome
  
horizons = [0.25, 0.5, 0.75]
time_horizons = np.quantile(T, horizons).tolist()

# %%
from synthcity.plugins.core.models.time_series_survival.benchmarks import (
     evaluate_ts_survival_model,
)


def eval_model(mod, **kwargs):
    n_folds = 3
    model = mod(**kwargs)
        
    score = evaluate_ts_survival_model(
        model, 
        static, temporal, temporal_horizons, T, E, 
        time_horizons,
        n_folds = n_folds
    )
    return score

# %%
from synthcity.plugins.core.models.time_series_survival import (
     DynamicDeephitTimeSeriesSurvival, rnn_modes, output_modes
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for output_mode in output_modes:
    for base in rnn_modes:
        score = eval_model(DynamicDeephitTimeSeriesSurvival, rnn_type = base, output_type = output_mode)["str"]
        local_results = pd.DataFrame([[f"DynDeephit[{base} -> {output_mode}]", score["c_index"], score["brier_score"]]], columns = headers)
        results = pd.concat([results, local_results], ignore_index = True)
    
tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>DynDeephit[GRU -&gt; MLP]                      </td><td>0.8213 +/- 0.0154</td><td>0.116 +/- 0.0109 </td></tr>\n<tr><td style="text-align: right;"> 1</td><td>DynDeephit[LSTM -&gt; MLP]                     </td><td>0.8115 +/- 0.0101</td><td>0.1237 +/- 0.0123</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>DynDeephit[RNN -&gt; MLP]                      </td><td>0.8356 +/- 0.012 </td><td>0.1103 +/- 0.003 </td></tr>\n<tr><td style="text-align: right;"> 3</td><td>DynDeephit[Transformer -&gt; MLP]              </td><td>0.826 +/- 0.0082 </td><td>0.1141 +/- 0.0053</td></tr>\n<tr><td style="text-align: right;"> 4</td><td>DynDeephit[Wavelet -&gt; MLP]                  </td><td>0.805 +/- 0.0307 </td><td>0.1255 +/- 0.0135</td></tr>\n<tr><td style="text-align: right;"> 5</td><td>DynDeephit[GRU -&gt; MiniRocket]               </td><td>0.796 +/- 0.0163 </td><td>0.1327 +/- 0.0114</td></tr>\n<tr><td style="text-align: right;"> 6</td><td>DynDeephit[LSTM -&gt; MiniRocket]              </td><td>0.7883 +/- 0.0083</td><td>0.1406 +/- 0.0059</td></tr>\n<tr><td style="text-align: right;"> 7</td><td>DynDeephit[RNN -&gt; MiniRocket]               </td><td>0.8257 +/- 0.0187</td><td>0.125 +/- 0.0104 </td></tr>\n<tr><td style="text-align: right;"> 8</td><td>DynDeephit[Transformer -&gt; MiniRocket]       </td><td>0.821 +/- 0.0133 </td><td>0.1229 +/- 0.0087</td></tr>\n<tr><td style="text-align: right;"> 9</td><td>DynDeephit[Wavelet -&gt; MiniRocket]           </td><td>0.7811 +/- 0.0245</td><td>0.1365 +/- 0.0124</td></tr>\n<tr><td style="text-align: right;">10</td><td>DynDeephit[GRU -&gt; mWDNPlus]                 </td><td>0.815 +/- 0.0123 </td><td>0.1266 +/- 0.0067</td></tr>\n<tr><td style="text-align: right;">11</td><td>DynDeephit[LSTM -&gt; mWDNPlus]                </td><td>0.816 +/- 0.0172 </td><td>0.1212 +/- 0.0144</td></tr>\n<tr><td style="text-align: right;">12</td><td>DynDeephit[RNN -&gt; mWDNPlus]                 </td><td>0.8421 +/- 0.0028</td><td>0.1166 +/- 0.0047</td></tr>\n<tr><td style="text-align: right;">13</td><td>DynDeephit[Transformer -&gt; mWDNPlus]         </td><td>0.786 +/- 0.0016 </td><td>0.141 +/- 0.0153 </td></tr>\n<tr><td style="text-align: right;">14</td><td>DynDeephit[Wavelet -&gt; mWDNPlus]             </td><td>0.7509 +/- 0.0556</td><td>0.1587 +/- 0.0325</td></tr>\n<tr><td style="text-align: right;">15</td><td>DynDeephit[GRU -&gt; Transformer]              </td><td>0.8173 +/- 0.0255</td><td>0.1165 +/- 0.0159</td></tr>\n<tr><td style="text-align: right;">16</td><td>DynDeephit[LSTM -&gt; Transformer]             </td><td>0.8015 +/- 0.0196</td><td>0.1278 +/- 0.0187</td></tr>\n<tr><td style="text-align: right;">17</td><td>DynDeephit[RNN -&gt; Transformer]              </td><td>0.8164 +/- 0.0259</td><td>0.1216 +/- 0.01  </td></tr>\n<tr><td style="text-align: right;">18</td><td>DynDeephit[Transformer -&gt; Transformer]      </td><td>0.8215 +/- 0.0246</td><td>0.1155 +/- 0.0172</td></tr>\n<tr><td style="text-align: right;">19</td><td>DynDeephit[Wavelet -&gt; Transformer]          </td><td>0.7876 +/- 0.0207</td><td>0.1321 +/- 0.01  </td></tr>\n<tr><td style="text-align: right;">20</td><td>DynDeephit[GRU -&gt; TSiTPlus]                 </td><td>0.8145 +/- 0.0267</td><td>0.1212 +/- 0.0131</td></tr>\n<tr><td style="text-align: right;">21</td><td>DynDeephit[LSTM -&gt; TSiTPlus]                </td><td>0.8028 +/- 0.0245</td><td>0.1286 +/- 0.0192</td></tr>\n<tr><td style="text-align: right;">22</td><td>DynDeephit[RNN -&gt; TSiTPlus]                 </td><td>0.8176 +/- 0.0146</td><td>0.12 +/- 0.0087  </td></tr>\n<tr><td style="text-align: right;">23</td><td>DynDeephit[Transformer -&gt; TSiTPlus]         </td><td>0.8232 +/- 0.0202</td><td>0.1121 +/- 0.0048</td></tr>\n<tr><td style="text-align: right;">24</td><td>DynDeephit[Wavelet -&gt; TSiTPlus]             </td><td>0.7856 +/- 0.0209</td><td>0.1326 +/- 0.0096</td></tr>\n<tr><td style="text-align: right;">25</td><td>DynDeephit ...

# %%
from synthcity.plugins.core.models.time_series_survival import (
     DynamicDeephitTimeSeriesSurvival, rnn_modes, output_modes
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for wavelet_type in ["haar", "db4", "db6", "sym2", "sym4", "sym14"]:
    base = "Wavelet"
    output_mode = "MLP"
    score = eval_model(DynamicDeephitTimeSeriesSurvival, 
                       rnn_type = base, 
                       output_type = output_mode, 
                       wavelet_type = wavelet_type,
                       wavelet_mode = "symmetric",
                      )["str"]
    local_results = pd.DataFrame([[f"DynDeephit[{base} -> {wavelet_type}]", score["c_index"], score["brier_score"]]], columns = headers)
    results = pd.concat([results, local_results], ignore_index = True)
    
tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;">0</td><td>DynDeephit[Wavelet -&gt; haar] </td><td>0.805 +/- 0.0307 </td><td>0.1255 +/- 0.0135</td></tr>\n<tr><td style="text-align: right;">1</td><td>DynDeephit[Wavelet -&gt; db4]  </td><td>0.7968 +/- 0.0202</td><td>0.1225 +/- 0.0055</td></tr>\n<tr><td style="text-align: right;">2</td><td>DynDeephit[Wavelet -&gt; db6]  </td><td>0.8108 +/- 0.0017</td><td>0.1212 +/- 0.007 </td></tr>\n<tr><td style="text-align: right;">3</td><td>DynDeephit[Wavelet -&gt; sym2] </td><td>0.8278 +/- 0.0032</td><td>0.1051 +/- 0.0074</td></tr>\n<tr><td style="text-align: right;">4</td><td>DynDeephit[Wavelet -&gt; sym4] </td><td>0.7888 +/- 0.0292</td><td>0.1299 +/- 0.0088</td></tr>\n<tr><td style="text-align: right;">5</td><td>DynDeephit[Wavelet -&gt; sym14]</td><td>0.8062 +/- 0.0382</td><td>0.1241 +/- 0.0182</td></tr>\n</tbody>\n</table>'

# %%
from synthcity.plugins.core.models.time_series_survival import (
     CoxTimeSeriesSurvival,
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for output_mode in output_modes:
    for base in rnn_modes:
        score = eval_model(CoxTimeSeriesSurvival, emb_rnn_type = base, emb_output_type = output_mode)["str"]
        local_results = pd.DataFrame([[f"CoxPH[{base} -> {output_mode}]", score["c_index"], score["brier_score"]]], columns = headers)
        results = pd.concat([results, local_results], ignore_index = True)

tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>CoxPH[GRU -&gt; MLP]                      </td><td>0.8505 +/- 0.0074</td><td>0.1008 +/- 0.0109</td></tr>\n<tr><td style="text-align: right;"> 1</td><td>CoxPH[LSTM -&gt; MLP]                     </td><td>0.8335 +/- 0.0023</td><td>0.1085 +/- 0.0076</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>CoxPH[RNN -&gt; MLP]                      </td><td>0.846 +/- 0.0099 </td><td>0.1059 +/- 0.0114</td></tr>\n<tr><td style="text-align: right;"> 3</td><td>CoxPH[Transformer -&gt; MLP]              </td><td>0.8222 +/- 0.0401</td><td>0.1201 +/- 0.0205</td></tr>\n<tr><td style="text-align: right;"> 4</td><td>CoxPH[Wavelet -&gt; MLP]                  </td><td>0.8146 +/- 0.0153</td><td>0.1298 +/- 0.02  </td></tr>\n<tr><td style="text-align: right;"> 5</td><td>CoxPH[GRU -&gt; MiniRocket]               </td><td>0.8294 +/- 0.0137</td><td>0.1128 +/- 0.0222</td></tr>\n<tr><td style="text-align: right;"> 6</td><td>CoxPH[LSTM -&gt; MiniRocket]              </td><td>0.8072 +/- 0.022 </td><td>0.1256 +/- 0.0217</td></tr>\n<tr><td style="text-align: right;"> 7</td><td>CoxPH[RNN -&gt; MiniRocket]               </td><td>0.8305 +/- 0.014 </td><td>0.1264 +/- 0.0055</td></tr>\n<tr><td style="text-align: right;"> 8</td><td>CoxPH[Transformer -&gt; MiniRocket]       </td><td>0.8102 +/- 0.0351</td><td>0.1269 +/- 0.0238</td></tr>\n<tr><td style="text-align: right;"> 9</td><td>CoxPH[Wavelet -&gt; MiniRocket]           </td><td>0.7869 +/- 0.0183</td><td>0.1508 +/- 0.0111</td></tr>\n<tr><td style="text-align: right;">10</td><td>CoxPH[GRU -&gt; mWDNPlus]                 </td><td>0.8271 +/- 0.0129</td><td>0.1184 +/- 0.0189</td></tr>\n<tr><td style="text-align: right;">11</td><td>CoxPH[LSTM -&gt; mWDNPlus]                </td><td>0.8222 +/- 0.0134</td><td>0.122 +/- 0.0163 </td></tr>\n<tr><td style="text-align: right;">12</td><td>CoxPH[RNN -&gt; mWDNPlus]                 </td><td>0.8497 +/- 0.0253</td><td>0.105 +/- 0.02   </td></tr>\n<tr><td style="text-align: right;">13</td><td>CoxPH[Transformer -&gt; mWDNPlus]         </td><td>0.7775 +/- 0.0271</td><td>0.1413 +/- 0.0236</td></tr>\n<tr><td style="text-align: right;">14</td><td>CoxPH[Wavelet -&gt; mWDNPlus]             </td><td>0.7789 +/- 0.0156</td><td>0.151 +/- 0.0037 </td></tr>\n<tr><td style="text-align: right;">15</td><td>CoxPH[GRU -&gt; Transformer]              </td><td>0.8459 +/- 0.0014</td><td>0.0999 +/- 0.0066</td></tr>\n<tr><td style="text-align: right;">16</td><td>CoxPH[LSTM -&gt; Transformer]             </td><td>0.8231 +/- 0.0098</td><td>0.1128 +/- 0.0133</td></tr>\n<tr><td style="text-align: right;">17</td><td>CoxPH[RNN -&gt; Transformer]              </td><td>0.8259 +/- 0.019 </td><td>0.1185 +/- 0.0115</td></tr>\n<tr><td style="text-align: right;">18</td><td>CoxPH[Transformer -&gt; Transformer]      </td><td>0.8165 +/- 0.0371</td><td>0.1275 +/- 0.0325</td></tr>\n<tr><td style="text-align: right;">19</td><td>CoxPH[Wavelet -&gt; Transformer]          </td><td>0.7526 +/- 0.0507</td><td>0.1594 +/- 0.0291</td></tr>\n<tr><td style="text-align: right;">20</td><td>CoxPH[GRU -&gt; TSiTPlus]                 </td><td>0.8405 +/- 0.0032</td><td>0.106 +/- 0.0134 </td></tr>\n<tr><td style="text-align: right;">21</td><td>CoxPH[LSTM -&gt; TSiTPlus]                </td><td>0.8209 +/- 0.0066</td><td>0.1137 +/- 0.0121</td></tr>\n<tr><td style="text-align: right;">22</td><td>CoxPH[RNN -&gt; TSiTPlus]                 </td><td>0.8421 +/- 0.0232</td><td>0.113 +/- 0.0166 </td></tr>\n<tr><td style="text-align: right;">23</td><td>CoxPH[Transformer -&gt; TSiTPlus]         </td><td>0.8258 +/- 0.0208</td><td>0.1224 +/- 0.0184</td></tr>\n<tr><td style="text-align: right;">24</td><td>CoxPH[Wavelet -&gt; TSiTPlus]             </td><td>0.7655 +/- 0.0645</td><td>0.1565 +/- 0.0512</td></tr>\n<tr><td style="text-align: right;">25</td><td>CoxPH[GRU -&gt; LSTM]                     </td><td>0.8537 +/- 0.0071</td><td>0.0963 +/- 0.0041</td></tr>\n<tr><td style="text-align: ri ...

# %%
from synthcity.plugins.core.models.time_series_survival import (
     CoxTimeSeriesSurvival,
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for wavelet_type in ["haar", "db4", "db6", "sym2", "sym4", "sym14"]:
    base = "Wavelet"
    output_mode = "MLP"
    score = eval_model(CoxTimeSeriesSurvival, 
                       emb_rnn_type = base, 
                       emb_output_type = output_mode,
                       emb_wavelet_type = wavelet_type,
                       emb_wavelet_mode = "symmetric",
    )["str"]

    local_results = pd.DataFrame([[f"CoxPH[{base} -> {wavelet_type}]", score["c_index"], score["brier_score"]]], columns = headers)
    results = pd.concat([results, local_results], ignore_index = True)
    
tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;">0</td><td>CoxPH[Wavelet -&gt; haar] </td><td>0.8146 +/- 0.0153</td><td>0.1298 +/- 0.02  </td></tr>\n<tr><td style="text-align: right;">1</td><td>CoxPH[Wavelet -&gt; db4]  </td><td>0.8185 +/- 0.0091</td><td>0.1309 +/- 0.027 </td></tr>\n<tr><td style="text-align: right;">2</td><td>CoxPH[Wavelet -&gt; db6]  </td><td>0.8224 +/- 0.0061</td><td>0.1316 +/- 0.0237</td></tr>\n<tr><td style="text-align: right;">3</td><td>CoxPH[Wavelet -&gt; sym2] </td><td>0.8279 +/- 0.0236</td><td>0.1255 +/- 0.0236</td></tr>\n<tr><td style="text-align: right;">4</td><td>CoxPH[Wavelet -&gt; sym4] </td><td>0.7986 +/- 0.0324</td><td>0.1348 +/- 0.0075</td></tr>\n<tr><td style="text-align: right;">5</td><td>CoxPH[Wavelet -&gt; sym14]</td><td>0.8264 +/- 0.0197</td><td>0.1106 +/- 0.0068</td></tr>\n</tbody>\n</table>'

# %%
from synthcity.plugins.core.models.time_series_survival import (
     XGBTimeSeriesSurvival,
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for output_mode in output_modes:
    for base in rnn_modes:
        score = eval_model(XGBTimeSeriesSurvival, emb_rnn_type = base, emb_output_type = output_mode)["str"]
        local_results = pd.DataFrame([[f"XGB[{base} -> {output_mode}]", score["c_index"], score["brier_score"]]], columns = headers)
        results = pd.concat([results, local_results], ignore_index = True)

tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;"> 0</td><td>XGB[GRU -&gt; MLP]                      </td><td>0.791 +/- 0.0089 </td><td>0.1425 +/- 0.0111</td></tr>\n<tr><td style="text-align: right;"> 1</td><td>XGB[LSTM -&gt; MLP]                     </td><td>0.7804 +/- 0.0165</td><td>0.1447 +/- 0.0148</td></tr>\n<tr><td style="text-align: right;"> 2</td><td>XGB[RNN -&gt; MLP]                      </td><td>0.7917 +/- 0.0194</td><td>0.1384 +/- 0.0194</td></tr>\n<tr><td style="text-align: right;"> 3</td><td>XGB[Transformer -&gt; MLP]              </td><td>0.802 +/- 0.0233 </td><td>0.1534 +/- 0.0324</td></tr>\n<tr><td style="text-align: right;"> 4</td><td>XGB[Wavelet -&gt; MLP]                  </td><td>0.7812 +/- 0.024 </td><td>0.1535 +/- 0.0187</td></tr>\n<tr><td style="text-align: right;"> 5</td><td>XGB[GRU -&gt; MiniRocket]               </td><td>0.7582 +/- 0.0432</td><td>0.1668 +/- 0.0363</td></tr>\n<tr><td style="text-align: right;"> 6</td><td>XGB[LSTM -&gt; MiniRocket]              </td><td>0.7421 +/- 0.0282</td><td>0.1749 +/- 0.029 </td></tr>\n<tr><td style="text-align: right;"> 7</td><td>XGB[RNN -&gt; MiniRocket]               </td><td>0.7856 +/- 0.0166</td><td>0.1666 +/- 0.0132</td></tr>\n<tr><td style="text-align: right;"> 8</td><td>XGB[Transformer -&gt; MiniRocket]       </td><td>0.7936 +/- 0.0145</td><td>0.1554 +/- 0.0257</td></tr>\n<tr><td style="text-align: right;"> 9</td><td>XGB[Wavelet -&gt; MiniRocket]           </td><td>0.7575 +/- 0.0117</td><td>0.1729 +/- 0.0159</td></tr>\n<tr><td style="text-align: right;">10</td><td>XGB[GRU -&gt; mWDNPlus]                 </td><td>0.7755 +/- 0.013 </td><td>0.1619 +/- 0.0281</td></tr>\n<tr><td style="text-align: right;">11</td><td>XGB[LSTM -&gt; mWDNPlus]                </td><td>0.7726 +/- 0.0225</td><td>0.1748 +/- 0.026 </td></tr>\n<tr><td style="text-align: right;">12</td><td>XGB[RNN -&gt; mWDNPlus]                 </td><td>0.8216 +/- 0.0313</td><td>0.1404 +/- 0.035 </td></tr>\n<tr><td style="text-align: right;">13</td><td>XGB[Transformer -&gt; mWDNPlus]         </td><td>0.7827 +/- 0.0393</td><td>0.1667 +/- 0.0394</td></tr>\n<tr><td style="text-align: right;">14</td><td>XGB[Wavelet -&gt; mWDNPlus]             </td><td>0.7427 +/- 0.031 </td><td>0.1685 +/- 0.0056</td></tr>\n<tr><td style="text-align: right;">15</td><td>XGB[GRU -&gt; Transformer]              </td><td>0.7946 +/- 0.032 </td><td>0.1422 +/- 0.0101</td></tr>\n<tr><td style="text-align: right;">16</td><td>XGB[LSTM -&gt; Transformer]             </td><td>0.7742 +/- 0.0107</td><td>0.156 +/- 0.0149 </td></tr>\n<tr><td style="text-align: right;">17</td><td>XGB[RNN -&gt; Transformer]              </td><td>0.787 +/- 0.0147 </td><td>0.1503 +/- 0.0168</td></tr>\n<tr><td style="text-align: right;">18</td><td>XGB[Transformer -&gt; Transformer]      </td><td>0.7848 +/- 0.049 </td><td>0.1588 +/- 0.0354</td></tr>\n<tr><td style="text-align: right;">19</td><td>XGB[Wavelet -&gt; Transformer]          </td><td>0.7458 +/- 0.018 </td><td>0.1765 +/- 0.0177</td></tr>\n<tr><td style="text-align: right;">20</td><td>XGB[GRU -&gt; TSiTPlus]                 </td><td>0.7804 +/- 0.0216</td><td>0.159 +/- 0.0219 </td></tr>\n<tr><td style="text-align: right;">21</td><td>XGB[LSTM -&gt; TSiTPlus]                </td><td>0.7759 +/- 0.0195</td><td>0.1562 +/- 0.0236</td></tr>\n<tr><td style="text-align: right;">22</td><td>XGB[RNN -&gt; TSiTPlus]                 </td><td>0.7933 +/- 0.0528</td><td>0.1543 +/- 0.0296</td></tr>\n<tr><td style="text-align: right;">23</td><td>XGB[Transformer -&gt; TSiTPlus]         </td><td>0.7758 +/- 0.0254</td><td>0.1656 +/- 0.0341</td></tr>\n<tr><td style="text-align: right;">24</td><td>XGB[Wavelet -&gt; TSiTPlus]             </td><td>0.7565 +/- 0.0281</td><td>0.1674 +/- 0.026 </td></tr>\n<tr><td style="text-align: right;">25</td><td>XGB[GRU -&gt; LSTM]                     </td><td>0.8049 +/- 0.0168</td><td>0.14 +/- 0.0153  </td></tr>\n<tr><td style="text-align: right;">26</td><td>XGB[LSTM -&gt; LSTM]                ...

# %%
from synthcity.plugins.core.models.time_series_survival import (
     XGBTimeSeriesSurvival,
 )

headers = ["Model", "C-Index", "Brier score"]
results = pd.DataFrame([], columns = headers)

for wavelet_type in ["haar", "db4", "db6", "sym2", "sym4", "sym14"]:
    base = "Wavelet"
    output_mode = "MLP"
    score = eval_model(XGBTimeSeriesSurvival, 
                       emb_rnn_type = base, 
                       emb_output_type = output_mode,
                       emb_wavelet_type = wavelet_type,
                       emb_wavelet_mode = "symmetric",
                      )["str"]
    local_results = pd.DataFrame([[f"XGB[{base} -> {wavelet_type}]", score["c_index"], score["brier_score"]]], columns = headers)
    results = pd.concat([results, local_results], ignore_index = True)

tabulate.tabulate(results, tablefmt='html')
# Out:
# '<table>\n<tbody>\n<tr><td style="text-align: right;">0</td><td>XGB[Wavelet -&gt; haar] </td><td>0.7812 +/- 0.024 </td><td>0.1535 +/- 0.0187</td></tr>\n<tr><td style="text-align: right;">1</td><td>XGB[Wavelet -&gt; db4]  </td><td>0.7852 +/- 0.011 </td><td>0.1616 +/- 0.0344</td></tr>\n<tr><td style="text-align: right;">2</td><td>XGB[Wavelet -&gt; db6]  </td><td>0.7866 +/- 0.0203</td><td>0.1761 +/- 0.0498</td></tr>\n<tr><td style="text-align: right;">3</td><td>XGB[Wavelet -&gt; sym2] </td><td>0.8063 +/- 0.0121</td><td>0.1359 +/- 0.0143</td></tr>\n<tr><td style="text-align: right;">4</td><td>XGB[Wavelet -&gt; sym4] </td><td>0.7519 +/- 0.0285</td><td>0.1705 +/- 0.0238</td></tr>\n<tr><td style="text-align: right;">5</td><td>XGB[Wavelet -&gt; sym14]</td><td>0.766 +/- 0.0256 </td><td>0.1542 +/- 0.0109</td></tr>\n</tbody>\n</table>'
